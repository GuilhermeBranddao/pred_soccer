# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime

pd.set_option('display.max_columns', 1000)
# pd.set_option('display.max_rows', 100)

# %%
import sqlite3
import pandas as pd
import os
from pathlib import Path


def create_connection(db_path):
    """Cria a conexão com o banco de dados SQLite."""
    connection = None
    try:
        connection = sqlite3.connect(db_path)

        print("Conexão SQLite estabelecida.")
    except sqlite3.Error as e:
        print(f"Erro ao conectar ao SQLite: {e}")
    return connection

BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('__file__'))))
DATA_DIR = os.path.join(BASE_DIR, 'database')
FT_DIR = os.path.join(BASE_DIR, 'modelagem', 'feature_eng', 'data')

conn = create_connection(db_path=Path(os.path.join(DATA_DIR, "soccer_data.db")))
country = "Brazil"
query = "SELECT * FROM soccer_data WHERE country = ?"

df_hist_soccer_matches = pd.read_sql_query(query, conn, params=(country,))

conn.close()
# Out:
# Conexão SQLite estabelecida.

# %%
df_hist_soccer_matches.head()
# Out:
#      id country   league season     home_team    away_team  home_score  \
# 0  5415  Brazil  Serie A   2012     Palmeiras   Portuguesa           1
# 1  5416  Brazil  Serie A   2012  Sport Recife  Flamengo RJ           1
# 2  5417  Brazil  Serie A   2012   Figueirense      Nautico           2
# 3  5418  Brazil  Serie A   2012   Botafogo RJ    Sao Paulo           4
# 4  5419  Brazil  Serie A   2012   Corinthians   Fluminense           0
#
#    away_score result  psch  pscd  psca  maxch  maxcd  maxca  avgch  avgcd  \
# 0           1      D  1.75  3.86  5.25   1.76   3.87   5.31   1.69   3.50
# 1           1      D  2.83  3.39  2.68   2.83   3.42   2.70   2.59   3.23
# 2           1      H  1.60  4.04  6.72   1.67   4.05   7.22   1.59   3.67
# 3           2      H  2.49  3.35  3.15   2.49   3.39   3.15   2.35   3.26
# 4           1      A  1.96  3.53  4.41   1.96   3.53   4.41   1.89   3.33
#
#    avgca  bfech  bfecd             datetime                  hash  \
# 0   4.90    NaN    NaN  2012-05-19 22:30:00  10444097902145517897
# 1   2.58    NaN    NaN  2012-05-19 22:30:00   7876314183501917566
# 2   5.64    NaN    NaN  2012-05-20 01:00:00   9296066046964045682
# 3   2.84    NaN    NaN  2012-05-20 20:00:00   3618841616446699339
# 4   3.89    NaN    NaN  2012-05-20 20:00:00  11994628649421207242
#
#           last_updated
# 0  2024-12-18 22:32:46
# 1  2024-12-18 22:32:46
# 2  2024-12-18 22:32:46
# 3  2024-12-18 22:32:46
# 4  2024-12-18 22:32:46

# %% [markdown]
# ## Agrupando dados

# %%
# def group_infos(df_home_team, away_team):
#     df_home_team = df_home_team.copy()
#     away_team = away_team.copy()
#     group_result_home_team = df_home_team.groupby(["home_team"]).agg(
#         gols_marcado_casa = ("home_score", "sum"),
#         gols_sofridos_casa = ("away_score", "sum"),
#         jogos_em_casa = ("away_score", "count"),
#     ).reset_index(names="time")

#     group_result_away_score = away_team.groupby(["away_team"]).agg(
#         gols_marcado_fora = ("away_score", "sum"),
#         gols_sofridos_fora = ("home_score", "sum"),
#         jogos_em_fora = ("away_score", "count"),
#     ).reset_index(names="time")

#     df_merge_data = pd.merge(group_result_home_team, group_result_away_score)
#     return df_merge_data

# %% [markdown]
# ## Calcumando a força de Ataque e Defesa

# %%
import numpy as np
import scipy.stats as stats

# Agrupando dados
def get_group_infos(away_team):
    group_result_home_team = away_team.groupby(["home_team"]).agg(
        gols_marcado_casa = ("home_score", "sum"),
        gols_sofridos_casa = ("away_score", "sum"),
        jogos_em_casa = ("away_score", "count"),
    ).reset_index(names="time")

    group_result_away_score = away_team.groupby(["away_team"]).agg(
        gols_marcado_fora = ("away_score", "sum"),
        gols_sofridos_fora = ("home_score", "sum"),
        jogos_em_fora = ("away_score", "count"),
    ).reset_index(names="time")

    df_merge_data = pd.merge(group_result_home_team, group_result_away_score)
    return df_merge_data

def calc_attack_and_defense_force(df_merge_data):
    df = df_merge_data.copy()
    # Gols marcados pelo time A em casa / Jogos em casa 
    df["attack_force_home_team"] = df["gols_marcado_casa"]/df["jogos_em_casa"].replace(0, 1)
    # Gols sofridos pelo time A em casa / Jogos em casa 
    df["defense_force_home_team"] = df["gols_sofridos_casa"]/df["jogos_em_casa"].replace(0, 1)

    # Gols marcados pelo time B fora de casa / Jogos fora de casa 
    df["attack_force_away_team"] = df["gols_marcado_fora"]/df["jogos_em_fora"].replace(0, 1)
    # Gols sofridos pelo time B fora de casa / Jogos fora de casa 
    df["defense_force_away_team"] = df["gols_sofridos_fora"]/df["jogos_em_fora"].replace(0, 1)


    # Normalizando valores
    # Média geral do campeonato: se um time fez muito mais gols que o outro seus numeros podem enganar, por isso da normalização
    league_avg_goals_home = df["gols_marcado_casa"].sum() / df["jogos_em_casa"].sum()
    league_avg_goals_away = df["gols_marcado_fora"].sum() / df["jogos_em_fora"].sum()

    # Normalizando
    df["attack_force_home_team"] /= league_avg_goals_home
    df["defense_force_home_team"] /= league_avg_goals_away
    df["attack_force_away_team"] /= league_avg_goals_away
    df["defense_force_away_team"] /= league_avg_goals_home


    # Gerando estimativas de gols esperados com a normalização
    df["expected_goals_home_team"] = league_avg_goals_home * df["attack_force_home_team"] * df["defense_force_away_team"]
    df["expected_goals_away_team"] = league_avg_goals_away * df["attack_force_away_team"] * df["defense_force_home_team"]

    return df


def get_goal_distribution(lambda_time: float, k_values: int = 6):
    """
    Calcula a distribuição de Poisson para gols esperados de um time.

    :param lambda_time: Média esperada de gols do time (float)
    :param k_values: Número máximo de gols a considerar (int)
    :return: Número de gols mais provável, probabilidade desse número de gols, e um dicionário com todas as probabilidades
    """
    k_range_values = np.arange(k_values)

    # Calcula a probabilidade para cada número de gols
    poisson_prob = stats.poisson.pmf(k_range_values, lambda_time)

    # Encontra o número de gols mais provável
    num_goals = np.argmax(poisson_prob)

    # Retorna também um dicionário com todas as probabilidades
    prob_dict = {k: round(prob, 6) for k, prob in zip(k_range_values, poisson_prob)}

    return num_goals, poisson_prob[num_goals], prob_dict

def get_probabilities_of_win_draw_loss(row:pd.Series, max_goals:int=5)->pd.Series:
    """
    Calcula a probabilidade de vitória, empate e derrota para um jogo específico.
    
    Parâmetros:
    row: Linha do DataFrame contendo 'prob_dict_home' e 'prob_dict_away'.
    max_goals: Número máximo de gols considerados.
    
    Retorna:
    (prob_home_win, prob_draw, prob_away_win)
    """
    
    prob_A = row["prob_dict_home"]
    prob_B = row["prob_dict_away"]

    prob_home_win = sum(
        prob_A[i] * sum(prob_B[j] for j in range(i))
        for i in range(1, max_goals+1)
    )

    prob_draw = sum(
        prob_A[i] * prob_B[i]
        for i in range(max_goals+1)
    )

    prob_away_win = sum(
        prob_B[j] * sum(prob_A[i] for i in range(j))
        for j in range(1, max_goals+1)
    )

    # print(f"Vitória do Time A: {prob_home_win:.4f} ({prob_home_win * 100:.2f}%)")
    # print(f"Empate: {prob_draw:.4f} ({prob_draw * 100:.2f}%)")
    # print(f"Vitória do Time B: {prob_away_win:.4f} ({prob_away_win * 100:.2f}%)")

    return prob_home_win, prob_draw, prob_away_win

def predict(df, name_home_team, name_away_team):
    df = df.copy()
    # Selecionar o Atlético-MG como time da casa
    home_team = df[df["time"] == name_home_team].iloc[0]

    # Selecionar o Sport Recife como time visitante
    away_team = df[df["time"] == name_away_team].iloc[0]

    # Criar um dicionário para simular a estrutura de um jogo
    game = {
        "prob_dict_home": home_team["prob_dict_home"],  # Atlético-MG como time da casa
        "prob_dict_away": away_team["prob_dict_away"],  # Sport Recife como visitante
    }

    # Calcular as probabilidades para o jogo específico
    prob_home_win, prob_draw, prob_away_win = get_probabilities_of_win_draw_loss(game)

    # Exibir os resultados
    # print(f"Probabilidade de Vitória do Atlético-MG: {prob_home_win:.2%}")
    # print(f"Probabilidade de Empate: {prob_draw:.2%}")
    # print(f"Probabilidade de Vitória do Sport Recife: {prob_away_win:.2%}")

    # print(prob_home_win, prob_draw, prob_away_win)
    result_text = ["H", "D", "A"]
    return result_text[np.argmax([prob_home_win, prob_draw, prob_away_win])]

# %%
df_hist_soccer_matches.head()
df_hist_soccer_matches["datetime"] = pd.to_datetime(df_hist_soccer_matches["datetime"])

# %%
def create_table_num_games(df:pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df = df.sort_values("datetime")  # Ordenar pelo tempo

    df_games = pd.concat([
        df[["datetime", "home_team"]].rename(columns={"home_team": "team"}),
        df[["datetime", "away_team"]].rename(columns={"away_team": "team"})
    ])

    df_games["games_played"] = 1  # Cada linha representa um jogo para o time
    df_games["total_games"] = df_games.groupby("team")["games_played"].cumsum()

    return df_games

# %%
qtd_min_jogos = 5
# Verifica se os time tem a quantidade minima de dias para calcular a probabilidade

df_simulation = df_hist_soccer_matches.iloc[0:500]

for id, row in df_simulation.iterrows():

    if id >= 100:
        break

    df_table_num_games = create_table_num_games(df_simulation)

    df_result = df_table_num_games[df_table_num_games["datetime"] < row["datetime"]]

    if df_result.empty:
        continue
        print("Dados infuficientes para gerar a probabilidade")

    # elif quanty_matchs_home_team < qtd_min_jogos:
    #     continue
    #     print(f"O time da cada tem apenas {quanty_matchs_home_team} jodos e não será possivel gerar a probabilidade")

    # elif quanty_matchs_home_team < qtd_min_jogos:
    #     continue
    #     print(f"O time visitante tem apenas {quanty_matchs_away_team} jodos e não será possivel gerar a probabilidade")
    
    matchs_home_team = df_result[df_result["team"]==row['home_team']]["total_games"]#.values[-1]
    matchs_away_team = df_result[df_result["team"]==row['away_team']]["total_games"]#.values[-1]

    if matchs_home_team.empty or matchs_away_team.empty:
        continue

    quanty_matchs_home_team = matchs_home_team.values[-1]
    quanty_matchs_away_team = matchs_away_team.values[-1]
    # df_times = 
    # df_merge_data = group_infos(df)
    # calc_attack_and_defense_force(df_merge_data)
    
    list_times = [row['home_team'], row['away_team']]
    
    # Parte 2: gerando grupos de informação
    df_roup_infos = get_group_infos(df_simulation)
    df_merge_data = df_roup_infos[df_roup_infos["time"].isin(list_times)]

    # Parte 3: Calculando força do ateque e defesa
    df_attack_and_defense_force = calc_attack_and_defense_force(df_merge_data)

    # Parte 4: Calculando a distribuição de gols


    df_attack_and_defense_force[['num_goals_expected_home', 'prob_num_goals_home', 'prob_dict_home']] = df_attack_and_defense_force['expected_goals_home_team'].apply(lambda x: pd.Series(get_goal_distribution(x)))
    df_attack_and_defense_force[['num_goals_expected_away', 'prob_num_goals_away', 'prob_dict_away']] = df_attack_and_defense_force['expected_goals_away_team'].apply(lambda x: pd.Series(get_goal_distribution(x)))

    # Parte 5: Prevendo resultados
    pred = predict(df_attack_and_defense_force, name_home_team=row['home_team'], name_away_team=row['home_team'])

    df_simulation.loc[id, "pred"] = pred
    # print(quanty_matchs_home_team, quanty_matchs_away_team)
# Out:
# /tmp/ipykernel_469702/146187993.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_simulation.loc[id, "pred"] = pred

# %%
df_simulation.dropna(subset="pred", inplace=True)

df_simulation[["season","home_team","away_team","home_score","away_score","result","pred",]]
# Out:
# /tmp/ipykernel_469702/2466195758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_simulation.dropna(subset="pred", inplace=True)
#    season    home_team      away_team  home_score  away_score result pred
# 10   2012  Atletico GO    Ponte Preta           1           1      D    H
# 11   2012  Flamengo RJ  Internacional           3           3      D    H
# 12   2012   Portuguesa          Vasco           0           1      A    H
# 13   2012      Nautico       Cruzeiro           0           0      D    H
# 14   2012  Atletico-MG    Corinthians           1           0      H    H
# ..    ...          ...            ...         ...         ...    ...  ...
# 95   2012  Flamengo RJ    Corinthians           0           3      A    H
# 96   2012    Sao Paulo          Vasco           0           1      A    H
# 97   2012  Atletico GO    Figueirense           3           2      H    H
# 98   2012     Coritiba      Palmeiras           1           1      D    H
# 99   2012   Fluminense          Bahia           4           0      H    H
#
# [90 rows x 7 columns]

# %% [markdown]
# ---

# %%
df_hist_soccer_matches["datetime"] = pd.to_datetime(df_hist_soccer_matches["datetime"])
df_hist_soccer_matches.sort_values("datetime", inplace=True)

# %%
# Time A ganhou do time B 1 vez
# Time B ganhou do time C 1 vez

# Qual a força de cada time?

# %%
import pandas as pd
from collections import defaultdict
from collections import defaultdict, Counter

import pandas as pd
from collections import defaultdict, deque

# Dados de exemplo
jogos_treino = [
    {"home_team": "Time A", "away_team": "Time B", "home_score": 2, "away_score": 0},
    {"home_team": "Time B", "away_team": "Time C", "home_score": 2, "away_score": 0},

    {"home_team": "Time A", "away_team": "Time D", "home_score": 2, "away_score": 0},
    {"home_team": "Time D", "away_team": "Time C", "home_score": 2, "away_score": 0},

    {"home_team": "Time E", "away_team": "Time B", "home_score": 2, "away_score": 0},
    {"home_team": "Time E", "away_team": "Time C", "home_score": 2, "away_score": 0},
    {"home_team": "Time E", "away_team": "Time D", "home_score": 2, "away_score": 0},

    {"home_team": "Time G", "away_team": "Time A", "home_score": 2, "away_score": 0},
    {"home_team": "Time G", "away_team": "Time D", "home_score": 2, "away_score": 0},
    {"home_team": "Time G", "away_team": "Time D", "home_score": 2, "away_score": 0},

    
]

jogos_teste = [
    {"home_team": "Time A", "away_team": "Time B", "home_score": 2, "away_score": 0},
    {"home_team": "Time B", "away_team": "Time C", "home_score": 2, "away_score": 0},
    {"home_team": "Time A", "away_team": "Time C", "home_score": 2, "away_score": 0},
    {"home_team": "Time C", "away_team": "Time A", "home_score": 1, "away_score": 0},  # Erro
    {"home_team": "Time B", "away_team": "Time A", "home_score": 1, "away_score": 0},  # Erro

]

from collections import defaultdict, deque
def criar_grafo_pesado():

    """
    Exemplo de uso

    > grafo = criar_grafo()

    > grafo["Time A"]["Time B"]["vitorias"] += 2
    > grafo["Time A"]["Time B"]["num_gols"] += 4

    > grafo["Time B"]["Time C"]["vitorias"] += 1
    > grafo["Time B"]["Time C"]["num_gols"] += 3
    """
    return defaultdict(lambda: defaultdict(lambda: {"vitorias": 0, "num_gols": 0}))

def calcular_forca_times(grafo, peso_indireto=0.5):
    forca = defaultdict(float)

    # Iterar sobre uma cópia das chaves do grafo para evitar erro
    for vencedor in list(grafo):
        for perdedor in grafo[vencedor]:
            forca[vencedor] += 1

            # Vitória indireta
            fila = deque([(perdedor, 1)])
            visitados = set()
            while fila:
                atual, nivel = fila.popleft()
                if atual in visitados or nivel > 3:
                    # print("Continua", atual, nivel)
                    if forca.get(atual, None) is None:
                        forca[atual] = 0
                        print("Atribuindo 0 para", atual)
                    continue
                visitados.add(atual)
                for proximo in grafo[atual]:
                    forca[vencedor] += peso_indireto ** nivel
                    fila.append((proximo, nivel + 1))

    return dict(forca)

# Função para construir o grafo de vitórias diretas

def construir_grafo_vitorias_pesado(jogos):
    grafo = defaultdict(Counter)
    grafo_pesado = criar_grafo_pesado()

    grafo
    for jogo in jogos:
        home, away = jogo["home_team"], jogo["away_team"]
        home_score, away_score = jogo["home_score"], jogo["away_score"]

        if home_score > away_score:
            # grafo[home][away] += 1
            grafo_pesado[home][away]["vitorias"] += 1
            grafo_pesado[home][away]["num_gols"] += home_score
            # grafo_pesado[away][home]["num_gols"] += away_score

        elif away_score > home_score:
            # grafo[away][home] += 1
            grafo_pesado[away][home]["vitorias"] += 1
            grafo_pesado[away][home]["num_gols"] += away_score
            # grafo_pesado[home][away]["num_gols"] += home_score
    
    return grafo_pesado

def construir_grafo_vitorias(jogos):
    grafo = defaultdict(set)
    for jogo in jogos:
        home, away = jogo["home_team"], jogo["away_team"]
        home_score, away_score = jogo["home_score"], jogo["away_score"]

        if home_score > away_score:
            grafo[home].add(away)
        elif away_score > home_score:
            grafo[away].add(home)
    return grafo

# Função para verificar se há um caminho (vitória indireta) entre dois times
def existe_caminho(grafo, vencedor, perdedor):
    visitados = set()
    fila = deque([vencedor])

    while fila:
        atual = fila.popleft()
        if atual == perdedor:
            return True
        if atual not in visitados:
            visitados.add(atual)
            fila.extend(grafo[atual] - visitados)
    return False

# Função de avaliação das hipóteses
def avaliar_hipoteses(grafo, jogos_teste):

    forca_times = calcular_forca_times(grafo)

    acertos = erros = 0

    for jogo in jogos_teste:
        home, away = jogo["home_team"], jogo["away_team"]
        home_score, away_score = jogo["home_score"], jogo["away_score"]

        if home_score == away_score:
            continue  # Ignora empates
        

        vencedor = home if home_score > away_score else away
        perdedor = away if home_score > away_score else home

    
        if existe_caminho(grafo, vencedor, perdedor):
            acertos += 1
        else:
            erros += 1

        print(f"Vencedor: {vencedor}, Perdedor: {perdedor} | Força {forca_times.get(vencedor, None)} vs {forca_times.get(perdedor, None)}  | acertos:{acertos} erros:{erros}")

    total = acertos + erros
    taxa_acerto = acertos / total * 100 if total > 0 else 0

    print(f"✅ Hipóteses confirmadas: {acertos}")
    print(f"❌ Hipóteses refutadas: {erros}")
    print(f"📊 Total de hipóteses testadas: {total}")
    print(f"🎯 Taxa de acerto: {taxa_acerto:.2f}%")

# Executa a lógica
grafo_modelo = construir_grafo_vitorias(jogos_treino)
grafo_modelo_pesado = construir_grafo_vitorias_pesado(jogos_treino)
avaliar_hipoteses(grafo_modelo, jogos_teste)
# Out:
# Atribuindo 0 para Time C
# Vencedor: Time A, Perdedor: Time B | Força 3.0 vs 1.0  | acertos:1 erros:0
# Vencedor: Time B, Perdedor: Time C | Força 1.0 vs 0  | acertos:2 erros:0
# Vencedor: Time A, Perdedor: Time C | Força 3.0 vs 0  | acertos:3 erros:0
# Vencedor: Time C, Perdedor: Time A | Força 0 vs 3.0  | acertos:3 erros:1
# Vencedor: Time B, Perdedor: Time A | Força 1.0 vs 3.0  | acertos:3 erros:2
# ✅ Hipóteses confirmadas: 3
# ❌ Hipóteses refutadas: 2
# 📊 Total de hipóteses testadas: 5
# 🎯 Taxa de acerto: 60.00%

# %%
grafo_modelo_pesado
# Out:
# defaultdict(<function __main__.criar_grafo_pesado.<locals>.<lambda>()>,
#             {'Time A': defaultdict(<function __main__.criar_grafo_pesado.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Time B': {'vitorias': 1, 'num_gols': 2},
#                           'Time D': {'vitorias': 1, 'num_gols': 2}}),
#              'Time B': defaultdict(<function __main__.criar_grafo_pesado.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Time C': {'vitorias': 1, 'num_gols': 2}}),
#              'Time D': defaultdict(<function __main__.criar_grafo_pesado.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Time C': {'vitorias': 1, 'num_gols': 2}}),
#              'Time E': defaultdict(<function __main__.criar_grafo_pesado.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Time B': {'vitorias': 1, 'num_gols': 2},
#                           'Time C': {'vitorias': 1, 'num_gols': 2},
#                           'Time D': {'vitorias': 1, 'num_gols': 2}}),
#              'Time G': defaultdict(<function __main__.criar_grafo_pesado.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Time A': {'vitorias': 1, 'num_gols': 2},
#                           'Time D': {'vitorias': 2, 'num_gols': 4}})})

# %%
# Out:
# defaultdict(<function __main__.criar_grafo.<locals>.<lambda>()>,
#             {'Time A': defaultdict(<function __main__.criar_grafo.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Time B': {'vitorias': 2, 'num_gols': 4}}),
#              'Time B': defaultdict(<function __main__.criar_grafo.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Time C': {'vitorias': 1, 'num_gols': 3}})})

# %%
grafo["Time A"]["Time B"]
# Out:
# {'vitorias': 2, 'num_gols': 4}

# %%
from pprint import pprint
pprint(grafo_modelo)
# Out:
# defaultdict(<class 'set'>,
#             {'Time A': {'Time D', 'Time B'},
#              'Time B': {'Time C'},
#              'Time C': set(),
#              'Time D': {'Time C'},
#              'Time E': {'Time C', 'Time D', 'Time B'},
#              'Time G': {'Time A', 'Time D'}})

# %%
calcular_forca_times(grafo_modelo)
# Out:
# defaultdict(<class 'set'>, {'Time A': {'Time D', 'Time B'}, 'Time B': {'Time C'}, 'Time D': {'Time C'}, 'Time E': {'Time C', 'Time D', 'Time B'}, 'Time G': {'Time A', 'Time D'}})
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 calcular_forca_times(grafo_modelo)
#
# Cell In[105], line 42, in calcular_forca_times(grafo, peso_indireto)
#      40 print(grafo)
#      41 # Cada time recebe 1 ponto por vitória direta
# ---> 42 for vencedor in grafo:
#      43     for perdedor in grafo[vencedor]:
#      44         forca[vencedor] += 1
#
# RuntimeError: dictionary changed size during iteration

# %%
df_season_2023 = df_hist_soccer_matches[df_hist_soccer_matches["season"].isin(['2022', '2023'])]
df_season_2024 = df_hist_soccer_matches[df_hist_soccer_matches["season"] == '2024']

jogos_treino = df_season_2023[["home_team","away_team","home_score","away_score"]].to_dict("records")
jogos_teste = df_season_2024[["home_team","away_team","home_score","away_score"]].iloc[0:-4].to_dict("records")

# Executa a lógica
grafo_modelo = construir_grafo_vitorias(jogos_treino)
avaliar_hipoteses(grafo_modelo, jogos_teste)
# Out:
# Atribuindo 0 para Juventude
# Atribuindo 0 para Bahia
# Atribuindo 0 para Gremio
# Atribuindo 0 para Vasco
# Atribuindo 0 para Bragantino
# Atribuindo 0 para Athletico-PR
# Atribuindo 0 para Atletico GO
# Atribuindo 0 para Cuiaba
# Atribuindo 0 para America MG
# Atribuindo 0 para Flamengo RJ
# Atribuindo 0 para Goias
# Atribuindo 0 para Santos
# Atribuindo 0 para Coritiba
# Atribuindo 0 para Cruzeiro
# Atribuindo 0 para Sao Paulo
# Atribuindo 0 para Corinthians
# Atribuindo 0 para Botafogo RJ
# Atribuindo 0 para Avai
# Atribuindo 0 para Internacional
# Atribuindo 0 para Fluminense
# Atribuindo 0 para Fortaleza
# Atribuindo 0 para Palmeiras
# Atribuindo 0 para Atletico-MG
# Vencedor: Internacional, Perdedor: Bahia | Força 1868.5 vs 958.625  | acertos:1 erros:0
# Vencedor: Fortaleza, Perdedor: Sao Paulo | Força 1475.875 vs 1505.625  | acertos:2 erros:0
# Vencedor: Vasco, Perdedor: Gremio | Força 797.125 vs 1383.75  | acertos:3 erros:0
# Vencedor: Flamengo RJ, Perdedor: Atletico GO | Força 1711.625 vs 442.0  | acertos:4 erros:0
# Vencedor: Athletico-PR, Perdedor: Cuiaba | Força 1713.75 vs 1330.875  | acertos:5 erros:0
# Vencedor: Cruzeiro, Perdedor: Botafogo RJ | Força 832.125 vs 1695.5  | acertos:6 erros:0
# Vencedor: Palmeiras, Perdedor: Vitoria | Força 1776.875 vs None  | acertos:6 erros:1
# Vencedor: Bahia, Perdedor: Fluminense | Força 958.625 vs 1658.375  | acertos:7 erros:1
# Vencedor: Bragantino, Perdedor: Vasco | Força 1366.0 vs 797.125  | acertos:8 erros:1
# Vencedor: Gremio, Perdedor: Athletico-PR | Força 1383.75 vs 1713.75  | acertos:9 erros:1
# Vencedor: Internacional, Perdedor: Palmeiras | Força 1868.5 vs 1776.875  | acertos:10 erros:1
# Vencedor: Juventude, Perdedor: Corinthians | Força 225.375 vs 1438.5  | acertos:11 erros:1
# Vencedor: Flamengo RJ, Perdedor: Sao Paulo | Força 1711.625 vs 1505.625  | acertos:12 erros:1
# Vencedor: Botafogo RJ, Perdedor: Atletico GO | Força 1695.5 vs 442.0  | acertos:13 erros:1
# Vencedor: Fluminense, Perdedor: Vasco | Força 1658.375 vs 797.125  | acertos:14 erros:1
# Vencedor: Bragantino, Perdedor: Corinthians | Força 1366.0 vs 1438.5  | acertos:15 erros:1
# Vencedor: Gremio, Perdedor: Cuiaba | Força 1383.75 vs 1330.875  | acertos:16 erros:1
# Vencedor: Atletico-MG, Perdedor: Cruzeiro | Força 1655.625 vs 832.125  | acertos:17 erros:1
# Vencedor: Athletico-PR, Perdedor: Internacional | Força 1713.75 vs 1868.5  | acertos:18 erros:1
# Vencedor: Sao Paulo, Perdedor: Atletico GO | Força 1505.625 vs 442.0  | acertos:19 erros:1
# Vencedor: Botafogo RJ, Perdedor: Juventude | Força 1695.5 vs 225.375  | acertos:20 erros:1
# Vencedor: Criciuma, Perdedor: Vasco | Força None vs 797.125  | acertos:20 erros:2
# Vencedor: Atletico-MG, Perdedor: Cuiaba | Força 1655.625 vs 1330.875  | acertos:21 erros:2
# Vencedor: Bahia, Perdedor: Gremio | Força 958.625 vs 1383.75  | acertos:22 erros:2
# Vencedor: Botafogo RJ, Perdedor: Flamengo RJ | Força 1695.5 vs 1711.625  | acertos:23 erros:2
# Vencedor: Cruzeiro, Perdedor: Vitoria | Força 832.125 vs None  | acertos:23 erros:3
# Vencedor: Corinthians, Perdedor: Fluminense | Força 1438.5 vs 1658.375  | acertos:24 erros:3
# Vencedor: Athletico-PR, Perdedor: Vasco | Força 1713.75 vs 797.125  | acertos:25 erros:3
# Vencedor: Sao Paulo, Perdedor: Vitoria | Força 1505.625 vs None  | acertos:25 erros:4
# Vencedor: Bahia, Perdedor: Botafogo RJ | Força 958.625 vs 1695.5  | acertos:26 erros:4
# Vencedor: Palmeiras, Perdedor: Cuiaba | Força 1776.875 vs 1330.875  | acertos:27 erros:4
# Vencedor: Flamengo RJ, Perdedor: Corinthians | Força 1711.625 vs 1438.5  | acertos:28 erros:4
# Vencedor: Athletico-PR, Perdedor: Palmeiras | Força 1713.75 vs 1776.875  | acertos:29 erros:4
# Vencedor: Cruzeiro, Perdedor: Atletico GO | Força 832.125 vs 442.0  | acertos:30 erros:4
# Vencedor: Vasco, Perdedor: Vitoria | Força 797.125 vs None  | acertos:30 erros:5
# Vencedor: Bahia, Perdedor: Bragantino | Força 958.625 vs 1366.0  | acertos:31 erros:5
# Vencedor: Sao Paulo, Perdedor: Fluminense | Força 1505.625 vs 1658.375  | acertos:32 erros:5
# Vencedor: Bragantino, Perdedor: Gremio | Força 1366.0 vs 1383.75  | acertos:33 erros:5
# Vencedor: Atletico GO, Perdedor: Vitoria | Força 442.0 vs None  | acertos:33 erros:6
# Vencedor: Internacional, Perdedor: Cuiaba | Força 1868.5 vs 1330.875  | acertos:34 erros:6
# Vencedor: Botafogo RJ, Perdedor: Corinthians | Força 1695.5 vs 1438.5  | acertos:35 erros:6
# Vencedor: Palmeiras, Perdedor: Criciuma | Força 1776.875 vs None  | acertos:35 erros:7
# Vencedor: Flamengo RJ, Perdedor: Vasco | Força 1711.625 vs 797.125  | acertos:36 erros:7
# Vencedor: Fortaleza, Perdedor: Athletico-PR | Força 1475.875 vs 1713.75  | acertos:37 erros:7
# Vencedor: Sao Paulo, Perdedor: Cruzeiro | Força 1505.625 vs 832.125  | acertos:38 erros:7
# Vencedor: Juventude, Perdedor: Atletico GO | Força 225.375 vs 442.0  | acertos:39 erros:7
# Vencedor: Cuiaba, Perdedor: Criciuma | Força 1330.875 vs None  | acertos:39 erros:8
# Vencedor: Botafogo RJ, Perdedor: Fluminense | Força 1695.5 vs 1658.375  | acertos:40 erros:8
# Vencedor: Atletico-MG, Perdedor: Bragantino | Força 1655.625 vs 1366.0  | acertos:41 erros:8
# Vencedor: Cruzeiro, Perdedor: Cuiaba | Força 832.125 vs 1330.875  | acertos:42 erros:8
# Vencedor: Flamengo RJ, Perdedor: Gremio | Força 1711.625 vs 1383.75  | acertos:43 erros:8
# Vencedor: Athletico-PR, Perdedor: Criciuma | Força 1713.75 vs None  | acertos:43 erros:9
# Vencedor: Bahia, Perdedor: Fortaleza | Força 958.625 vs 1475.875  | acertos:44 erros:9
# Vencedor: Palmeiras, Perdedor: Vasco | Força 1776.875 vs 797.125  | acertos:45 erros:9
# Vencedor: Bragantino, Perdedor: Juventude | Força 1366.0 vs 225.375  | acertos:46 erros:9
# Vencedor: Atletico GO, Perdedor: Fluminense | Força 442.0 vs 1658.375  | acertos:47 erros:9
# Vencedor: Vitoria, Perdedor: Internacional | Força None vs 1868.5  | acertos:47 erros:10
# Vencedor: Cuiaba, Perdedor: Fortaleza | Força 1330.875 vs 1475.875  | acertos:48 erros:10
# Vencedor: Botafogo RJ, Perdedor: Gremio | Força 1695.5 vs 1383.75  | acertos:49 erros:10
# Vencedor: Palmeiras, Perdedor: Atletico-MG | Força 1776.875 vs 1655.625  | acertos:50 erros:10
# Vencedor: Criciuma, Perdedor: Atletico GO | Força None vs 442.0  | acertos:50 erros:11
# Vencedor: Juventude, Perdedor: Vasco | Força 225.375 vs 797.125  | acertos:51 erros:11
# Vencedor: Cuiaba, Perdedor: Sao Paulo | Força 1330.875 vs 1505.625  | acertos:52 erros:11
# Vencedor: Fortaleza, Perdedor: Gremio | Força 1475.875 vs 1383.75  | acertos:53 erros:11
# Vencedor: Cruzeiro, Perdedor: Fluminense | Força 832.125 vs 1658.375  | acertos:54 erros:11
# Vencedor: Internacional, Perdedor: Corinthians | Força 1868.5 vs 1438.5  | acertos:55 erros:11
# Vencedor: Vitoria, Perdedor: Atletico-MG | Força None vs 1655.625  | acertos:55 erros:12
# Vencedor: Flamengo RJ, Perdedor: Bahia | Força 1711.625 vs 958.625  | acertos:56 erros:12
# Vencedor: Palmeiras, Perdedor: Bragantino | Força 1776.875 vs 1366.0  | acertos:57 erros:12
# Vencedor: Criciuma, Perdedor: Botafogo RJ | Força None vs 1695.5  | acertos:57 erros:13
# Vencedor: Internacional, Perdedor: Gremio | Força 1868.5 vs 1383.75  | acertos:58 erros:13
# Vencedor: Vasco, Perdedor: Sao Paulo | Força 797.125 vs 1505.625  | acertos:59 erros:13
# Vencedor: Bahia, Perdedor: Cruzeiro | Força 958.625 vs 832.125  | acertos:60 erros:13
# Vencedor: Flamengo RJ, Perdedor: Fluminense | Força 1711.625 vs 1658.375  | acertos:61 erros:13
# Vencedor: Bragantino, Perdedor: Vitoria | Força 1366.0 vs None  | acertos:61 erros:14
# Vencedor: Palmeiras, Perdedor: Juventude | Força 1776.875 vs 225.375  | acertos:62 erros:14
# Vencedor: Cruzeiro, Perdedor: Athletico-PR | Força 832.125 vs 1713.75  | acertos:63 erros:14
# Vencedor: Botafogo RJ, Perdedor: Bragantino | Força 1695.5 vs 1366.0  | acertos:64 erros:14
# Vencedor: Juventude, Perdedor: Flamengo RJ | Força 225.375 vs 1711.625  | acertos:65 erros:14
# Vencedor: Bahia, Perdedor: Vasco | Força 958.625 vs 797.125  | acertos:66 erros:14
# Vencedor: Fortaleza, Perdedor: Palmeiras | Força 1475.875 vs 1776.875  | acertos:67 erros:14
# Vencedor: Atletico-MG, Perdedor: Internacional | Força 1655.625 vs 1868.5  | acertos:68 erros:14
# Vencedor: Vitoria, Perdedor: Fluminense | Força None vs 1658.375  | acertos:68 erros:15
# Vencedor: Sao Paulo, Perdedor: Criciuma | Força 1505.625 vs None  | acertos:68 erros:16
# Vencedor: Fortaleza, Perdedor: Juventude | Força 1475.875 vs 225.375  | acertos:69 erros:16
# Vencedor: Gremio, Perdedor: Fluminense | Força 1383.75 vs 1658.375  | acertos:70 erros:16
# Vencedor: Sao Paulo, Perdedor: Bahia | Força 1505.625 vs 958.625  | acertos:71 erros:16
# Vencedor: Flamengo RJ, Perdedor: Cruzeiro | Força 1711.625 vs 832.125  | acertos:72 erros:16
# Vencedor: Athletico-PR, Perdedor: Vitoria | Força 1713.75 vs None  | acertos:72 erros:17
# Vencedor: Palmeiras, Perdedor: Corinthians | Força 1776.875 vs 1438.5  | acertos:73 erros:17
# Vencedor: Botafogo RJ, Perdedor: Cuiaba | Força 1695.5 vs 1330.875  | acertos:74 erros:17
# Vencedor: Vasco, Perdedor: Fortaleza | Força 797.125 vs 1475.875  | acertos:75 erros:17
# Vencedor: Criciuma, Perdedor: Cruzeiro | Força None vs 832.125  | acertos:75 erros:18
# Vencedor: Sao Paulo, Perdedor: Athletico-PR | Força 1505.625 vs 1713.75  | acertos:76 erros:18
# Vencedor: Flamengo RJ, Perdedor: Atletico-MG | Força 1711.625 vs 1655.625  | acertos:77 erros:18
# Vencedor: Bragantino, Perdedor: Atletico GO | Força 1366.0 vs 442.0  | acertos:78 erros:18
# Vencedor: Bahia, Perdedor: Juventude | Força 958.625 vs 225.375  | acertos:79 erros:18
# Vencedor: Corinthians, Perdedor: Vitoria | Força 1438.5 vs None  | acertos:79 erros:19
# Vencedor: Sao Paulo, Perdedor: Bragantino | Força 1505.625 vs 1366.0  | acertos:80 erros:19
# Vencedor: Cruzeiro, Perdedor: Corinthians | Força 832.125 vs 1438.5  | acertos:81 erros:19
# Vencedor: Fortaleza, Perdedor: Fluminense | Força 1475.875 vs 1658.375  | acertos:82 erros:19
# Vencedor: Juventude, Perdedor: Gremio | Força 225.375 vs 1383.75  | acertos:83 erros:19
# Vencedor: Vasco, Perdedor: Internacional | Força 797.125 vs 1868.5  | acertos:84 erros:19
# Vencedor: Athletico-PR, Perdedor: Atletico GO | Força 1713.75 vs 442.0  | acertos:85 erros:19
# Vencedor: Palmeiras, Perdedor: Bahia | Força 1776.875 vs 958.625  | acertos:86 erros:19
# Vencedor: Vitoria, Perdedor: Criciuma | Força None vs None  | acertos:86 erros:20
# Vencedor: Botafogo RJ, Perdedor: Atletico-MG | Força 1695.5 vs 1655.625  | acertos:87 erros:20
# Vencedor: Cruzeiro, Perdedor: Gremio | Força 832.125 vs 1383.75  | acertos:88 erros:20
# Vencedor: Vasco, Perdedor: Corinthians | Força 797.125 vs 1438.5  | acertos:89 erros:20
# Vencedor: Bahia, Perdedor: Athletico-PR | Força 958.625 vs 1713.75  | acertos:90 erros:20
# Vencedor: Palmeiras, Perdedor: Atletico GO | Força 1776.875 vs 442.0  | acertos:91 erros:20
# Vencedor: Fortaleza, Perdedor: Flamengo RJ | Força 1475.875 vs 1711.625  | acertos:92 erros:20
# Vencedor: Atletico-MG, Perdedor: Sao Paulo | Força 1655.625 vs 1505.625  | acertos:93 erros:20
# Vencedor: Botafogo RJ, Perdedor: Vitoria | Força 1695.5 vs None  | acertos:93 erros:21
# Vencedor: Cuiaba, Perdedor: Bahia | Força 1330.875 vs 958.625  | acertos:94 erros:21
# Vencedor: Cruzeiro, Perdedor: Bragantino | Força 832.125 vs 1366.0  | acertos:95 erros:21
# Vencedor: Corinthians, Perdedor: Criciuma | Força 1438.5 vs None  | acertos:95 erros:22
# Vencedor: Vasco, Perdedor: Atletico GO | Força 797.125 vs 442.0  | acertos:96 erros:22
# Vencedor: Sao Paulo, Perdedor: Gremio | Força 1505.625 vs 1383.75  | acertos:97 erros:22
# Vencedor: Botafogo RJ, Perdedor: Palmeiras | Força 1695.5 vs 1776.875  | acertos:98 erros:22
# Vencedor: Fortaleza, Perdedor: Vitoria | Força 1475.875 vs None  | acertos:98 erros:23
# Vencedor: Flamengo RJ, Perdedor: Criciuma | Força 1711.625 vs None  | acertos:98 erros:24
# Vencedor: Botafogo RJ, Perdedor: Internacional | Força 1695.5 vs 1868.5  | acertos:99 erros:24
# Vencedor: Palmeiras, Perdedor: Cruzeiro | Força 1776.875 vs 832.125  | acertos:100 erros:24
# Vencedor: Gremio, Perdedor: Vitoria | Força 1383.75 vs None  | acertos:100 erros:25
# Vencedor: Corinthians, Perdedor: Bahia | Força 1438.5 vs 958.625  | acertos:101 erros:25
# Vencedor: Atletico-MG, Perdedor: Vasco | Força 1655.625 vs 797.125  | acertos:102 erros:25
# Vencedor: Bragantino, Perdedor: Athletico-PR | Força 1366.0 vs 1713.75  | acertos:103 erros:25
# Vencedor: Fortaleza, Perdedor: Atletico GO | Força 1475.875 vs 442.0  | acertos:104 erros:25
# Vencedor: Fluminense, Perdedor: Cuiaba | Força 1658.375 vs 1330.875  | acertos:105 erros:25
# Vencedor: Cruzeiro, Perdedor: Juventude | Força 832.125 vs 225.375  | acertos:106 erros:25
# Vencedor: Flamengo RJ, Perdedor: Vitoria | Força 1711.625 vs None  | acertos:106 erros:26
# Vencedor: Fluminense, Perdedor: Palmeiras | Força 1658.375 vs 1776.875  | acertos:107 erros:26
# Vencedor: Criciuma, Perdedor: Juventude | Força None vs 225.375  | acertos:107 erros:27
# Vencedor: Vitoria, Perdedor: Palmeiras | Força None vs 1776.875  | acertos:107 erros:28
# Vencedor: Cruzeiro, Perdedor: Botafogo RJ | Força 832.125 vs 1695.5  | acertos:108 erros:28
# Vencedor: Fortaleza, Perdedor: Sao Paulo | Força 1475.875 vs 1505.625  | acertos:109 erros:28
# Vencedor: Fluminense, Perdedor: Bragantino | Força 1658.375 vs 1366.0  | acertos:110 erros:28
# Vencedor: Flamengo RJ, Perdedor: Atletico GO | Força 1711.625 vs 442.0  | acertos:111 erros:28
# Vencedor: Atletico-MG, Perdedor: Corinthians | Força 1655.625 vs 1438.5  | acertos:112 erros:28
# Vencedor: Athletico-PR, Perdedor: Cuiaba | Força 1713.75 vs 1330.875  | acertos:113 erros:28
# Vencedor: Gremio, Perdedor: Vasco | Força 1383.75 vs 797.125  | acertos:114 erros:28
# Vencedor: Vitoria, Perdedor: Cuiaba | Força None vs 1330.875  | acertos:114 erros:29
# Vencedor: Botafogo RJ, Perdedor: Atletico GO | Força 1695.5 vs 442.0  | acertos:115 erros:29
# Vencedor: Criciuma, Perdedor: Atletico-MG | Força None vs 1655.625  | acertos:115 erros:30
# Vencedor: Sao Paulo, Perdedor: Flamengo RJ | Força 1505.625 vs 1711.625  | acertos:116 erros:30
# Vencedor: Gremio, Perdedor: Athletico-PR | Força 1383.75 vs 1713.75  | acertos:117 erros:30
# Vencedor: Fluminense, Perdedor: Bahia | Força 1658.375 vs 958.625  | acertos:118 erros:30
# Vencedor: Fortaleza, Perdedor: Cruzeiro | Força 1475.875 vs 832.125  | acertos:119 erros:30
# Vencedor: Fortaleza, Perdedor: Criciuma | Força 1475.875 vs None  | acertos:119 erros:31
# Vencedor: Gremio, Perdedor: Cuiaba | Força 1383.75 vs 1330.875  | acertos:120 erros:31
# Vencedor: Vasco, Perdedor: Fluminense | Força 797.125 vs 1658.375  | acertos:121 erros:31
# Vencedor: Juventude, Perdedor: Botafogo RJ | Força 225.375 vs 1695.5  | acertos:122 erros:31
# Vencedor: Bahia, Perdedor: Vitoria | Força 958.625 vs None  | acertos:122 erros:32
# Vencedor: Sao Paulo, Perdedor: Atletico GO | Força 1505.625 vs 442.0  | acertos:123 erros:32
# Vencedor: Internacional, Perdedor: Juventude | Força 1868.5 vs 225.375  | acertos:124 erros:32
# Vencedor: Bahia, Perdedor: Gremio | Força 958.625 vs 1383.75  | acertos:125 erros:32
# Vencedor: Fortaleza, Perdedor: Bragantino | Força 1475.875 vs 1366.0  | acertos:126 erros:32
# Vencedor: Atletico GO, Perdedor: Internacional | Força 442.0 vs 1868.5  | acertos:127 erros:32
# Vencedor: Palmeiras, Perdedor: Sao Paulo | Força 1776.875 vs 1505.625  | acertos:128 erros:32
# Vencedor: Juventude, Perdedor: Athletico-PR | Força 225.375 vs 1713.75  | acertos:129 erros:32
# Vencedor: Botafogo RJ, Perdedor: Flamengo RJ | Força 1695.5 vs 1711.625  | acertos:130 erros:32
# Vencedor: Atletico GO, Perdedor: Juventude | Força 442.0 vs 225.375  | acertos:131 erros:32
# Vencedor: Palmeiras, Perdedor: Cuiaba | Força 1776.875 vs 1330.875  | acertos:132 erros:32
# Vencedor: Fluminense, Perdedor: Atletico-MG | Força 1658.375 vs 1655.625  | acertos:133 erros:32
# Vencedor: Fortaleza, Perdedor: Corinthians | Força 1475.875 vs 1438.5  | acertos:134 erros:32
# Vencedor: Gremio, Perdedor: Criciuma | Força 1383.75 vs None  | acertos:134 erros:33
# Vencedor: Sao Paulo, Perdedor: Vitoria | Força 1505.625 vs None  | acertos:134 erros:34
# Vencedor: Internacional, Perdedor: Cruzeiro | Força 1868.5 vs 832.125  | acertos:135 erros:34
# Vencedor: Flamengo RJ, Perdedor: Bragantino | Força 1711.625 vs 1366.0  | acertos:136 erros:34
# Vencedor: Vasco, Perdedor: Athletico-PR | Força 797.125 vs 1713.75  | acertos:137 erros:34
# Vencedor: Criciuma, Perdedor: Bragantino | Força None vs 1366.0  | acertos:137 erros:35
# Vencedor: Cuiaba, Perdedor: Criciuma | Força 1330.875 vs None  | acertos:137 erros:36
# Vencedor: Botafogo RJ, Perdedor: Fortaleza | Força 1695.5 vs 1475.875  | acertos:138 erros:36
# Vencedor: Cruzeiro, Perdedor: Atletico GO | Força 832.125 vs 442.0  | acertos:139 erros:36
# Vencedor: Atletico-MG, Perdedor: Gremio | Força 1655.625 vs 1383.75  | acertos:140 erros:36
# Vencedor: Corinthians, Perdedor: Flamengo RJ | Força 1438.5 vs 1711.625  | acertos:141 erros:36
# Vencedor: Palmeiras, Perdedor: Athletico-PR | Força 1776.875 vs 1713.75  | acertos:142 erros:36
# Vencedor: Bragantino, Perdedor: Bahia | Força 1366.0 vs 958.625  | acertos:143 erros:36
# Vencedor: Fluminense, Perdedor: Sao Paulo | Força 1658.375 vs 1505.625  | acertos:144 erros:36
# Vencedor: Internacional, Perdedor: Juventude | Força 1868.5 vs 225.375  | acertos:145 erros:36
# Vencedor: Vasco, Perdedor: Vitoria | Força 797.125 vs None  | acertos:145 erros:37
# Vencedor: Internacional, Perdedor: Fortaleza | Força 1868.5 vs 1475.875  | acertos:146 erros:37
# Vencedor: Vitoria, Perdedor: Atletico GO | Força None vs 442.0  | acertos:146 erros:38
# Vencedor: Botafogo RJ, Perdedor: Corinthians | Força 1695.5 vs 1438.5  | acertos:147 erros:38
# Vencedor: Juventude, Perdedor: Fluminense | Força 225.375 vs 1658.375  | acertos:148 erros:38
# Vencedor: Palmeiras, Perdedor: Criciuma | Força 1776.875 vs None  | acertos:148 erros:39
# Vencedor: Sao Paulo, Perdedor: Cruzeiro | Força 1505.625 vs 832.125  | acertos:149 erros:39
# Vencedor: Bahia, Perdedor: Atletico-MG | Força 958.625 vs 1655.625  | acertos:150 erros:39
# Vencedor: Internacional, Perdedor: Cuiaba | Força 1868.5 vs 1330.875  | acertos:151 erros:39
# Vencedor: Corinthians, Perdedor: Atletico GO | Força 1438.5 vs 442.0  | acertos:152 erros:39
# Vencedor: Vitoria, Perdedor: Juventude | Força None vs 225.375  | acertos:152 erros:40
# Vencedor: Botafogo RJ, Perdedor: Fluminense | Força 1695.5 vs 1658.375  | acertos:153 erros:40
# Vencedor: Fortaleza, Perdedor: Bahia | Força 1475.875 vs 958.625  | acertos:154 erros:40
# Vencedor: Atletico-MG, Perdedor: Bragantino | Força 1655.625 vs 1366.0  | acertos:155 erros:40
# Vencedor: Palmeiras, Perdedor: Vasco | Força 1776.875 vs 797.125  | acertos:156 erros:40
# Vencedor: Internacional, Perdedor: Sao Paulo | Força 1868.5 vs 1505.625  | acertos:157 erros:40
# Vencedor: Gremio, Perdedor: Flamengo RJ | Força 1383.75 vs 1711.625  | acertos:158 erros:40
# Vencedor: Criciuma, Perdedor: Gremio | Força None vs 1383.75  | acertos:158 erros:41
# Vencedor: Palmeiras, Perdedor: Atletico-MG | Força 1776.875 vs 1655.625  | acertos:159 erros:41
# Vencedor: Fortaleza, Perdedor: Cuiaba | Força 1475.875 vs 1330.875  | acertos:160 erros:41
# Vencedor: Sao Paulo, Perdedor: Corinthians | Força 1505.625 vs 1438.5  | acertos:161 erros:41
# Vencedor: Atletico GO, Perdedor: Fluminense | Força 442.0 vs 1658.375  | acertos:162 erros:41
# Vencedor: Bahia, Perdedor: Criciuma | Força 958.625 vs None  | acertos:162 erros:42
# Vencedor: Internacional, Perdedor: Vitoria | Força 1868.5 vs None  | acertos:162 erros:43
# Vencedor: Flamengo RJ, Perdedor: Athletico-PR | Força 1711.625 vs 1713.75  | acertos:163 erros:43
# Vencedor: Criciuma, Perdedor: Atletico GO | Força None vs 442.0  | acertos:163 erros:44
# Vencedor: Fluminense, Perdedor: Cruzeiro | Força 1658.375 vs 832.125  | acertos:164 erros:44
# Vencedor: Gremio, Perdedor: Fortaleza | Força 1383.75 vs 1475.875  | acertos:165 erros:44
# Vencedor: Botafogo RJ, Perdedor: Athletico-PR | Força 1695.5 vs 1713.75  | acertos:166 erros:44
# Vencedor: Flamengo RJ, Perdedor: Bahia | Força 1711.625 vs 958.625  | acertos:167 erros:44
# Vencedor: Cuiaba, Perdedor: Sao Paulo | Força 1330.875 vs 1505.625  | acertos:168 erros:44
# Vencedor: Atletico-MG, Perdedor: Gremio | Força 1655.625 vs 1383.75  | acertos:169 erros:44
# Vencedor: Sao Paulo, Perdedor: Vasco | Força 1505.625 vs 797.125  | acertos:170 erros:44
# Vencedor: Corinthians, Perdedor: Athletico-PR | Força 1438.5 vs 1713.75  | acertos:171 erros:44
# Vencedor: Fluminense, Perdedor: Flamengo RJ | Força 1658.375 vs 1711.625  | acertos:172 erros:44
# Vencedor: Internacional, Perdedor: Gremio | Força 1868.5 vs 1383.75  | acertos:173 erros:44
# Vencedor: Vitoria, Perdedor: Bragantino | Força None vs 1366.0  | acertos:173 erros:45
# Vencedor: Palmeiras, Perdedor: Juventude | Força 1776.875 vs 225.375  | acertos:174 erros:45
# Vencedor: Fluminense, Perdedor: Athletico-PR | Força 1658.375 vs 1713.75  | acertos:175 erros:45
# Vencedor: Vasco, Perdedor: Cuiaba | Força 797.125 vs 1330.875  | acertos:176 erros:45
# Vencedor: Flamengo RJ, Perdedor: Juventude | Força 1711.625 vs 225.375  | acertos:177 erros:45
# Vencedor: Gremio, Perdedor: Atletico GO | Força 1383.75 vs 442.0  | acertos:178 erros:45
# Vencedor: Vitoria, Perdedor: Fluminense | Força None vs 1658.375  | acertos:178 erros:46
# Vencedor: Athletico-PR, Perdedor: Cruzeiro | Força 1713.75 vs 832.125  | acertos:179 erros:46
# Vencedor: Internacional, Perdedor: Atletico-MG | Força 1868.5 vs 1655.625  | acertos:180 erros:46
# Vencedor: Botafogo RJ, Perdedor: Bragantino | Força 1695.5 vs 1366.0  | acertos:181 erros:46
# Vencedor: Corinthians, Perdedor: Cuiaba | Força 1438.5 vs 1330.875  | acertos:182 erros:46
# Vencedor: Vasco, Perdedor: Bahia | Força 797.125 vs 958.625  | acertos:183 erros:46
# Vencedor: Vitoria, Perdedor: Athletico-PR | Força None vs 1713.75  | acertos:183 erros:47
# Vencedor: Fortaleza, Perdedor: Juventude | Força 1475.875 vs 225.375  | acertos:184 erros:47
# Vencedor: Corinthians, Perdedor: Palmeiras | Força 1438.5 vs 1776.875  | acertos:185 erros:47
# Vencedor: Internacional, Perdedor: Criciuma | Força 1868.5 vs None  | acertos:185 erros:48
# Vencedor: Sao Paulo, Perdedor: Bahia | Força 1505.625 vs 958.625  | acertos:186 erros:48
# Vencedor: Botafogo RJ, Perdedor: Vasco | Força 1695.5 vs 797.125  | acertos:187 erros:48
# Vencedor: Atletico GO, Perdedor: Atletico-MG | Força 442.0 vs 1655.625  | acertos:188 erros:48
# Vencedor: Flamengo RJ, Perdedor: Cruzeiro | Força 1711.625 vs 832.125  | acertos:189 erros:48
# Vencedor: Internacional, Perdedor: Fluminense | Força 1868.5 vs 1658.375  | acertos:190 erros:48
# Vencedor: Palmeiras, Perdedor: Gremio | Força 1776.875 vs 1383.75  | acertos:191 erros:48
# Vencedor: Corinthians, Perdedor: Vitoria | Força 1438.5 vs None  | acertos:191 erros:49
# Vencedor: Cruzeiro, Perdedor: Criciuma | Força 832.125 vs None  | acertos:191 erros:50
# Vencedor: Fortaleza, Perdedor: Vasco | Força 1475.875 vs 797.125  | acertos:192 erros:50
# Vencedor: Juventude, Perdedor: Bahia | Força 225.375 vs 958.625  | acertos:193 erros:50
# Vencedor: Sao Paulo, Perdedor: Athletico-PR | Força 1505.625 vs 1713.75  | acertos:194 erros:50
# Vencedor: Athletico-PR, Perdedor: Atletico-MG | Força 1713.75 vs 1655.625  | acertos:195 erros:50
# Vencedor: Corinthians, Perdedor: Cruzeiro | Força 1438.5 vs 832.125  | acertos:196 erros:50
# Vencedor: Vitoria, Perdedor: Criciuma | Força None vs None  | acertos:196 erros:51
# Vencedor: Athletico-PR, Perdedor: Atletico GO | Força 1713.75 vs 442.0  | acertos:197 erros:51
# Vencedor: Palmeiras, Perdedor: Bahia | Força 1776.875 vs 958.625  | acertos:198 erros:51
# Vencedor: Flamengo RJ, Perdedor: Cuiaba | Força 1711.625 vs 1330.875  | acertos:199 erros:51
# Vencedor: Internacional, Perdedor: Vasco | Força 1868.5 vs 797.125  | acertos:200 erros:51
# Vencedor: Palmeiras, Perdedor: Atletico GO | Força 1776.875 vs 442.0  | acertos:201 erros:51
# Vencedor: Corinthians, Perdedor: Vasco | Força 1438.5 vs 797.125  | acertos:202 erros:51
# Vencedor: Internacional, Perdedor: Bragantino | Força 1868.5 vs 1366.0  | acertos:203 erros:51
# Vencedor: Botafogo RJ, Perdedor: Palmeiras | Força 1695.5 vs 1776.875  | acertos:204 erros:51
# Vencedor: Juventude, Perdedor: Atletico-MG | Força 225.375 vs 1655.625  | acertos:205 erros:51
# Vencedor: Corinthians, Perdedor: Criciuma | Força 1438.5 vs None  | acertos:205 erros:52
# Vencedor: Bahia, Perdedor: Cuiaba | Força 958.625 vs 1330.875  | acertos:206 erros:52
# Vencedor: Flamengo RJ, Perdedor: Internacional | Força 1711.625 vs 1868.5  | acertos:207 erros:52
# Vencedor: Gremio, Perdedor: Sao Paulo | Força 1383.75 vs 1505.625  | acertos:208 erros:52
# Vencedor: Vitoria, Perdedor: Fortaleza | Força None vs 1475.875  | acertos:208 erros:53
# Vencedor: Corinthians, Perdedor: Bahia | Força 1438.5 vs 958.625  | acertos:209 erros:53
# Vencedor: Vasco, Perdedor: Atletico-MG | Força 797.125 vs 1655.625  | acertos:210 erros:53
# Vencedor: Flamengo RJ, Perdedor: Criciuma | Força 1711.625 vs None  | acertos:210 erros:54
# Vencedor: Juventude, Perdedor: Sao Paulo | Força 225.375 vs 1505.625  | acertos:211 erros:54
# Vencedor: Palmeiras, Perdedor: Cruzeiro | Força 1776.875 vs 832.125  | acertos:212 erros:54
# Vencedor: Atletico GO, Perdedor: Fortaleza | Força 442.0 vs 1475.875  | acertos:213 erros:54
# Vencedor: Botafogo RJ, Perdedor: Internacional | Força 1695.5 vs 1868.5  | acertos:214 erros:54
# Vencedor: Fluminense, Perdedor: Cuiaba | Força 1658.375 vs 1330.875  | acertos:215 erros:54
# Vencedor: Bragantino, Perdedor: Athletico-PR | Força 1366.0 vs 1713.75  | acertos:216 erros:54
# Vencedor: Fortaleza, Perdedor: Internacional | Força 1475.875 vs 1868.5  | acertos:217 erros:54
# Vencedor: Corinthians, Perdedor: Gremio | Força 1438.5 vs 1383.75  | acertos:218 erros:54
# Vencedor: Vasco, Perdedor: Cuiaba | Força 797.125 vs 1330.875  | acertos:219 erros:54
# Vencedor: Cruzeiro, Perdedor: Juventude | Força 832.125 vs 225.375  | acertos:220 erros:54
# Vencedor: Botafogo RJ, Perdedor: Sao Paulo | Força 1695.5 vs 1505.625  | acertos:221 erros:54
# ✅ Hipóteses confirmadas: 221
# ❌ Hipóteses refutadas: 54
# 📊 Total de hipóteses testadas: 275
# 🎯 Taxa de acerto: 80.36%

# %%
df_season_2024[["home_team","away_team","home_score","away_score"]].iloc[-4:]
# Out:
#         home_team     away_team  home_score  away_score
# 4930        Bahia   Atletico GO           2           0
# 4929  Atletico-MG  Athletico-PR           1           0
# 4932   Bragantino      Criciuma           5           1
# 4938    Palmeiras    Fluminense           0           1

# %%
def estimar_probabilidade_vitoria(grafo, time_a, time_b):
    a_vence_b = existe_caminho(grafo, time_a, time_b)
    b_vence_a = existe_caminho(grafo, time_b, time_a)

    if a_vence_b and not b_vence_a:
        return {time_a: 0.9, time_b: 0.1}
    elif b_vence_a and not a_vence_b:
        return {time_a: 0.1, time_b: 0.9}
    elif a_vence_b and b_vence_a:
        return {time_a: 0.5, time_b: 0.5}
    else:
        # Nenhum caminho encontrado — jogo indefinido
        return {time_a: 0.33, time_b: 0.33, "empate": 0.34}

grafo, time_a, time_b = grafo_modelo, "Corinthians", "Criciuma"
estimar_probabilidade_vitoria(grafo, time_a, time_b)
# Out:
# {'Corinthians': 0.33, 'Criciuma': 0.33, 'empate': 0.34}

# %%
existe_caminho(grafo, time_a, time_b)
# Out:
# False

# %%
def verificar_transitividade(grafo, df):
    acertos = 0
    erros = 0
    total = 0

    for time_a in grafo:
        for time_b in grafo[time_a]:
            for time_c in grafo[time_b]:
                if time_c == time_a:  # evitar ciclos triviais
                    continue
                total += 1
                # Verificar se time_a realmente venceu time_c
                confronto = df[
                    ((df["home_team"] == time_a) & (df["away_team"] == time_c)) |
                    ((df["home_team"] == time_c) & (df["away_team"] == time_a))
                ]

                for _, row in confronto.iterrows():
                    if (row["home_team"] == time_a and row["home_score"] > row["away_score"]) or \
                       (row["away_team"] == time_a and row["away_score"] > row["home_score"]):
                        acertos += 1
                    else:
                        erros += 1
    return acertos, erros, total
# Out:
# defaultdict(set, {'Time A': {'Time B', 'Time C'}, 'Time B': {'Time C'}})

# %%
import pandas as pd
from collections import defaultdict

def construir_grafo_vitorias(df):
    grafo = defaultdict(set)
    for _, row in df.iterrows():
        home = row["home_team"]
        away = row["away_team"]
        home_score = row["home_score"]
        away_score = row["away_score"]

        if home_score > away_score:
            grafo[home].add(away)
        elif away_score > home_score:
            grafo[away].add(home)
    return grafo

def verificar_transitividade(grafo, df):
    acertos = 0
    erros = 0
    total = 0

    for time_a in grafo:
        for time_b in grafo[time_a]:
            for time_c in grafo[time_b]:
                if time_c == time_a:  # evitar ciclos triviais
                    continue
                total += 1
                # Verificar se time_a realmente venceu time_c
                confronto = df[
                    ((df["home_team"] == time_a) & (df["away_team"] == time_c)) |
                    ((df["home_team"] == time_c) & (df["away_team"] == time_a))
                ]

                for _, row in confronto.iterrows():
                    if (row["home_team"] == time_a and row["home_score"] > row["away_score"]) or \
                       (row["away_team"] == time_a and row["away_score"] > row["home_score"]):
                        acertos += 1
                    else:
                        erros += 1
    return acertos, erros, total

# Filtra temporada
df_season = df_hist_soccer_matches[df_hist_soccer_matches["season"] == '2024']

# Cria grafo de vitórias
grafo = construir_grafo_vitorias(df_season)

# Testa a hipótese de transitividade
acertos, erros, total = verificar_transitividade(grafo, df_season)

print(f"✅ Hipóteses confirmadas: {acertos}")
print(f"❌ Hipóteses refutadas: {erros}")
print(f"📊 Total de hipóteses testadas: {total}")
print(f"🎯 Taxa de acerto: {(acertos / total * 100):.2f}%" if total > 0 else "Sem dados suficientes.")
# Out:
# ✅ Hipóteses confirmadas: 1874
# ❌ Hipóteses refutadas: 2744
# 📊 Total de hipóteses testadas: 2309
# 🎯 Taxa de acerto: 81.16%

# %%
df_season.shape
# Out:
# (380, 23)

# %%
# Disputas historicas entre time A e time B
def get_historical_matches(df:pd.DataFrame, team_a:str, team_b:str) -> pd.DataFrame:
    """
    Filtra os jogos históricos entre dois times específicos.
    
    Parâmetros:
    df: DataFrame contendo os dados dos jogos.
    team_a: Nome do time A (string).
    team_b: Nome do time B (string).
    
    Retorna:
    DataFrame filtrado com os jogos entre os dois times.
    """
    
    # Filtra os jogos onde o time A é o mandante ou o time B é o mandante
    df_filtered = df[((df["home_team"] == team_a) & (df["away_team"] == team_b)) | 
                     ((df["home_team"] == team_b) & (df["away_team"] == team_a))]
    
    return df_filtered

# Exemplo de uso
team_a = "Palmeiras"
team_b = "Botafogo RJ"
historical_matches = get_historical_matches(df_hist_soccer_matches, team_a, team_b)

historical_matches
# Out:
#          id country   league season    home_team    away_team  home_score  \
# 143    5558  Brazil  Serie A   2012  Botafogo RJ    Palmeiras           1
# 334    5749  Brazil  Serie A   2012    Palmeiras  Botafogo RJ           2
# 830    6245  Brazil  Serie A   2014    Palmeiras  Botafogo RJ           0
# 1020   6435  Brazil  Serie A   2014  Botafogo RJ    Palmeiras           0
# 1689   7104  Brazil  Serie A   2016  Botafogo RJ    Palmeiras           3
# 1873   7288  Brazil  Serie A   2016    Palmeiras  Botafogo RJ           1
# 2073   7488  Brazil  Serie A   2017  Botafogo RJ    Palmeiras           1
# 2268   7683  Brazil  Serie A   2017    Palmeiras  Botafogo RJ           2
# 2287   7702  Brazil  Serie A   2018  Botafogo RJ    Palmeiras           1
# 2469   7884  Brazil  Serie A   2018    Palmeiras  Botafogo RJ           2
# 2709   8124  Brazil  Serie A   2019  Botafogo RJ    Palmeiras           0
# 2901   8316  Brazil  Serie A   2019    Palmeiras  Botafogo RJ           1
# 3170   8585  Brazil  Serie A   2020  Botafogo RJ    Palmeiras           2
# 3367   8782  Brazil  Serie A   2020    Palmeiras  Botafogo RJ           1
# 3896   9311  Brazil  Serie A   2022    Palmeiras  Botafogo RJ           4
# 4087   9502  Brazil  Serie A   2022  Botafogo RJ    Palmeiras           1
# 4294   9709  Brazil  Serie A   2023    Palmeiras  Botafogo RJ           0
# 4482   9897  Brazil  Serie A   2023  Botafogo RJ    Palmeiras           3
# 4718  10133  Brazil  Serie A   2024  Botafogo RJ    Palmeiras           1
# 4909  10324  Brazil  Serie A   2024    Palmeiras  Botafogo RJ           1
#
#       away_score result  psch  pscd   psca  maxch  maxcd  maxca  avgch  avgcd  \
# 143            2      A  1.83  3.63   5.03   1.92   3.63   5.03   1.81   3.37
# 334            2      D  2.04  3.68   3.75   2.04   3.68   4.20   1.92   3.39
# 830            2      A  2.41  3.28   3.27   2.50   3.28   3.60   2.32   3.15
# 1020           1      A  2.50  3.59   2.90   2.50   3.80   3.10   2.42   3.29
# 1689           1      H  2.64  3.52   2.77   2.92   3.54   2.77   2.63   3.26
# 1873           0      H  1.53  4.28   7.28   1.56   4.28   7.50   1.52   3.91
# 2073           2      A  2.86  3.19   2.77   2.87   3.25   2.80   2.71   3.09
# 2268           0      H  1.72  3.91   5.29   1.82   3.96   5.29   1.73   3.68
# 2287           1      D  3.89  3.37   2.12   3.90   3.38   2.16   3.61   3.23
# 2469           0      H  1.39  4.66   9.92   1.40   4.90  10.02   1.37   4.58
# 2709           1      A  8.64  4.39   1.43  10.00   4.39   1.48   8.15   4.13
# 2901           0      H  1.24  6.00  13.97   1.28   6.00  15.00   1.24   5.61
# 3170           1      H  4.12  3.24   2.07   4.29   3.30   2.10   3.94   3.16
# 3367           1      D  1.50  4.54   6.59   1.56   4.57   7.00   1.49   4.25
# 3896           0      H  1.39  5.07   8.21   1.43   5.10   8.25   1.40   4.73
# 4087           3      A  5.22  3.67   1.76   5.96   3.70   1.85   4.95   3.52
# 4294           1      A  1.45  4.73   7.59   1.53   4.75   7.59   1.45   4.46
# 4482           4      A  3.14  3.20   2.52   3.21   3.26   2.63   2.97   3.12
# 4718           0      H  2.91  3.28   2.60   2.91   3.33   2.65   2.79   3.23
# 4909           3      A  2.08  3.30   3.99   2.11   3.40   4.33   2.05   3.24
#
#       avgca  bfech  bfecd            datetime                  hash  \
# 143    4.29    NaN    NaN 2012-08-09 01:50:00   8097749072569523101
# 334    3.78    NaN    NaN 2012-11-04 19:00:00  10292364221432528697
# 830    3.05    NaN    NaN 2014-05-28 23:30:00  11594969873000332558
# 1020   2.80    NaN    NaN 2014-10-08 23:30:00  10149767242096788880
# 1689   2.62    NaN    NaN 2016-07-31 22:30:00   1712359202054989202
# 1873   6.48    NaN    NaN 2016-11-20 19:00:00   4653750769588602250
# 2073   2.64    NaN    NaN 2017-08-03 01:45:00  16610081012943574654
# 2268   4.61    NaN    NaN 2017-11-27 22:00:00   9217996348445472149
# 2287   2.08    NaN    NaN 2018-04-17 00:00:00  18351812539867471458
# 2469   8.68    NaN    NaN 2018-08-23 01:00:00   6091143423004721607
# 2709   1.42    NaN    NaN 2019-05-25 20:00:00   6816727219902826340
# 2901  12.51    NaN    NaN 2019-10-13 01:00:00  11614888559955667349
# 3170   2.01    NaN    NaN 2020-10-08 01:30:00   3738120611184895215
# 3367   6.28    NaN    NaN 2021-02-02 19:00:00  14725879195159653837
# 3896   7.48    NaN    NaN 2022-06-09 23:00:00   3344995144699720813
# 4087   1.75    NaN    NaN 2022-10-04 00:00:00   1208374367799654642
# 4294   6.74    NaN    NaN 2023-06-25 20:00:00   3147873826552152530
# 4482   2.49    NaN    NaN 2023-11-02 00:30:00  13727508414397595743
# 4718   2.56   3.05   3.35 2024-07-18 01:30:00    905837914569956121
# 4909   3.90   2.08   3.40 2024-11-27 00:30:00  13883708747974016739
#
#              last_updated
# 143   2024-12-18 22:32:46
# 334   2024-12-18 22:32:46
# 830   2024-12-18 22:32:46
# 1020  2024-12-18 22:32:46
# 1689  2024-12-18 22:32:46
# 1873  2024-12-18 22:32:46
# 2073  2024-12-18 22:32:46
# 2268  2024-12-18 22:32:46
# 2287  2024-12-18 22:32:46
# 2469  2024-12-18 22:32:46
# 2709  2024-12-18 22:32:46
# 2901  2024-12-18 22:32:46
# 3170  2024-12-18 22:32:46
# 3367  2024-12-18 22:32:46
# 3896  2024-12-18 22:32:46
# 4087  2024-12-18 22:32:46
# 4294  2024-12-18 22:32:46
# 4482  2024-12-18 22:32:46
# 4718  2024-12-18 22:32:46
# 4909  2024-12-18 22:32:46

# %%
# Casa season os times tem desempenhos diferentes, tenho que medir a força a cada season

# No jogo entre Palmeiras vs Botafogo RJ o time visitante venceu o time da casa por 1x3, esse resultado era experado levando em conta o desemenho dos dois times?

# %%
df_hist_soccer_matches["home_team"].unique()
# Out:
# array(['Palmeiras', 'Sport Recife', 'Figueirense', 'Botafogo RJ',
#        'Corinthians', 'Internacional', 'Ponte Preta', 'Cruzeiro', 'Vasco',
#        'Bahia', 'Atletico GO', 'Flamengo RJ', 'Portuguesa', 'Nautico',
#        'Sao Paulo', 'Atletico-MG', 'Coritiba', 'Santos', 'Gremio',
#        'Fluminense', 'Vitoria', 'Criciuma', 'Athletico-PR', 'Goias',
#        'Chapecoense-SC', 'Avai', 'Joinville', 'Santa Cruz', 'America MG',
#        'Parana', 'Ceara', 'CSA', 'Fortaleza', 'Bragantino', 'Cuiaba',
#        'Juventude'], dtype=object)
